# %% [markdown]
# # Tutorial 0 - Introduction to Python
#
# In this notebook you will review:
# - definition of a function
# - basic commands of the libraries NumPy and matplotlib
#
# So let's go!
#
# ---
# ## Step 1: import the relevant packages

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1:
# Create a function called `circle`that takes in input a positive real number and returns the area and circumference of the corresponding circle. Try your functions with values 3, 5, -1. In the last case, the function shall not compute the radius and complain!

# %%
# Write your function here

# %%
# Test your function here

# %% [markdown]
# ### Exercise 2:
# The Archimedean spiral can be parametrized as follows:
# $$x = r(\theta)\cdot\cos(\theta)$$
# $$y = r(\theta)\cdot\sin(\theta)$$
# $$r(\theta) = b\theta$$
# Plot an Archimedean spiral with angle $\theta \in [0, 6\pi]$ a a suitable choice for `b`.
# Feel free to experiment different types of spirals!

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 3
# 1. Create an image (100,100) with a black background. (Use numpy!)
# 2. Create a disk centered in the middle of the picture with grey color and a small white square inside centred in the middle of the picture.
# 3. Plot the image.
# 4. Extract row 50 and plot it as a 1D signal.

# %%
# Write your solution here
